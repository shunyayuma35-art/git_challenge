# %% [markdown]
# <a href="https://colab.research.google.com/github/shunyayuma35-art/git_challenge/blob/pull_request/kadai_015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def printinfo(self):
        print(self.name)
        print(self.age)

# インスタンス作成
person = Human("Taro", 25)

# 出力
person.printinfo()
# Out:
# Taro
# 25
